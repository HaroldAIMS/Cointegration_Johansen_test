# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
# === Run for multiple domains (auto-select best model) ===

def select_best_model(df, y_col, candidate_models=None, significance_level=0.10):
    if candidate_models is None:
        candidate_models = ["Base", "AR", "ARX", "LagX", "AR_LagX"]
    results = []
    for mtype in candidate_models:
        try:
            data, y, X = build_model_data(df.copy(), y_col, mtype)
            y_current = data[y_col]
            X_reg = data.drop(columns=["Months", y_col])
            X_reg = sm.add_constant(X_reg, has_constant='add')

            split_idx = int(len(data) * 0.8)
            y_train, y_test = y_current[:split_idx], y_current[split_idx:]
            X_train, X_test = X_reg[:split_idx], X_reg[split_idx:]

            # fit with backward elimination
            model, X_train_sel = backward_elimination(y_train, X_train, significance_level=significance_level)

            # ensure selected training columns are unique
            X_train_sel = X_train_sel.loc[:, ~X_train_sel.columns.duplicated()]

            # prepare test matrix (unique columns) and add missing cols with zeros
            X_test_const = sm.add_constant(X_test, has_constant='add')
            X_test_const = X_test_const.loc[:, ~X_test_const.columns.duplicated()]
            missing = [c for c in X_train_sel.columns if c not in X_test_const.columns]
            for c in missing:
                X_test_const[c] = 0.0

            # align order and types to model parameters (final safety)
            X_test_sel = X_test_const.reindex(columns=X_train_sel.columns).fillna(0)
            X_test_sel = X_test_sel.reindex(columns=model.params.index).astype(float)

            # predictions and metric
            y_test_pred = model.predict(X_test_sel)
            rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

            results.append({
                "model_type": mtype,
                "rmse_test": rmse_test,
                "aic": getattr(model, "aic", np.nan),
                "bic": getattr(model, "bic", np.nan),
                "rsq": getattr(model, "rsquared", np.nan)
            })
        except Exception as e:
            results.append({"model_type": mtype, "rmse_test": np.inf, "aic": np.inf, "bic": np.inf, "rsq": np.nan, "error": str(e)})
    df_res = pd.DataFrame(results).sort_values(["rmse_test", "aic"], ascending=[True, True])
    best = df_res.iloc[0].to_dict()
    print("\nModel selection results (sorted):")
    print(df_res[["model_type","rmse_test","aic","bic","rsq"]])
    print(f"\nSelected best model: {best['model_type']} (rmse_test={best['rmse_test']:.4f}, aic={best['aic']})")
    return best["model_type"], df_res

# === Backward Elimination ===
def backward_elimination(y, X, significance_level=0.10):
    X = X.copy()
    X = X.loc[:, ~X.columns.duplicated()]
    X = sm.add_constant(X, has_constant='add')

    model = sm.OLS(y, X).fit()
    while True:
        p_values = model.pvalues
        max_pval = p_values.max()
        worst_var = p_values.idxmax()

        if max_pval <= significance_level or worst_var == "const":
            break

        print(f"Dropping '{worst_var}' (p-value = {max_pval:.4f})")
        if worst_var in X.columns:
            X = X.drop(columns=[worst_var])
        X = X.loc[:, ~X.columns.duplicated()]
        model = sm.OLS(y, X).fit()

    X = X.loc[:, ~X.columns.duplicated()]
    return model, X


# === Function: Build Model Data According to Type ===
def build_model_data(df, y_col, model_type="Base"):
    y = df[y_col]
    X = df.drop(columns=[y_col, "Months"])
    X = sm.add_constant(X, has_constant='add')

    if model_type == "Base":
        data = pd.concat([df["Months"], y, X], axis=1).dropna()

    elif model_type == "AR":
        y_lagged = y.shift(1).rename("lag_y")
        data = pd.concat([df["Months"], y, y_lagged], axis=1).dropna()

    elif model_type == "ARX":
        y_lagged = y.shift(1).rename("lag_y")
        data = pd.concat([df["Months"], y, y_lagged, X], axis=1).dropna()

    elif model_type == "LagX":
        X_lagged = X.shift(1).rename(columns=lambda c: f"lag_{c}" if c != "const" else c)
        data = pd.concat([df["Months"], y, X_lagged], axis=1).dropna()

    elif model_type == "AR_LagX":
        y_lagged = y.shift(1).rename("lag_y")
        X_lagged = X.shift(1).rename(columns=lambda c: f"lag_{c}" if c != "const" else c)
        data = pd.concat([df["Months"], y, y_lagged, X_lagged], axis=1).dropna()

    else:
        raise ValueError("Unknown model type")

    return data, y, X


# === Function: Train, Evaluate, Forecast ===
def run_ols_forecast(df, y_col, model_type="Base", n_forecast=6):
    print(f"\n{'='*40}\nProcessing domain: {y_col} | Model type: {model_type}\n{'='*40}")

    data, y, X = build_model_data(df, y_col, model_type)
    y_current = data[y_col]
    X_reg = data.drop(columns=["Months", y_col])
    X_reg = sm.add_constant(X_reg, has_constant='add')

    # --- Train/Test split (80/20) ---
    split_idx = int(len(data) * 0.8)
    y_train, y_test = y_current[:split_idx], y_current[split_idx:]
    X_train, X_test = X_reg[:split_idx], X_reg[split_idx:]
    dates_train, dates_test = data["Months"][:split_idx], data["Months"][split_idx:]

    # --- Fit model with backward elimination ---
    model, X_train_sel = backward_elimination(y_train, X_train)

    # ensure selected training columns are unique
    X_train_sel = X_train_sel.loc[:, ~X_train_sel.columns.duplicated()]

    # prepare test matrix and add missing columns with zeros
    X_test_const = sm.add_constant(X_test, has_constant='add')
    X_test_const = X_test_const.loc[:, ~X_test_const.columns.duplicated()]
    missing = [c for c in X_train_sel.columns if c not in X_test_const.columns]
    for c in missing:
        X_test_const[c] = 0

    # align columns and types with the fitted model before predicting
    X_test_sel = X_test_const.reindex(columns=X_train_sel.columns).fillna(0)
    X_test_sel = X_test_sel.reindex(columns=model.params.index).astype(float)

    # also ensure training selection is ordered like model.params and float
    X_train_sel = X_train_sel.reindex(columns=model.params.index).astype(float)

    # --- Predictions ---
    y_train_pred = model.predict(X_train_sel)
    y_test_pred = model.predict(X_test_sel)

    # --- Performance ---
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    print(f"R² (train): {model.rsquared:.4f} | Adj R²: {model.rsquared_adj:.4f}")
    print(f"RMSE (train): {rmse_train:.4f} | RMSE (test): {rmse_test:.4f}")

    # --- Forecast next n months ---
    forecast_dates = pd.date_range(start=data["Months"].iloc[-1] + pd.offsets.MonthBegin(1),
                                   periods=n_forecast, freq="MS")
    last_row = data.iloc[-1:].copy()
    current_y = y_current.iloc[-1]
    forecasts = []

    for date in forecast_dates:
        row = last_row.copy()
        if "lag_y" in X_train_sel.columns:
            row["lag_y"] = current_y
        row = row.loc[:, ~row.columns.duplicated()]
        row_input = row.reindex(columns=X_train_sel.columns).fillna(0)
        row_input = row_input.reindex(columns=model.params.index).astype(float)
        pred = float(np.asarray(model.predict(row_input)).ravel()[0])
        forecasts.append(pred)
        current_y = pred

    forecast_df = pd.DataFrame({"Months": forecast_dates, "Forecasted CPI": forecasts})

    # --- Plots ---
    plt.figure(figsize=(10, 4))
    plt.plot(dates_train, y_train, label="Actual (Train)", color="blue")
    plt.plot(dates_train, y_train_pred, label="Predicted (Train)", linestyle="--", color="cyan")
    plt.plot(dates_test, y_test, label="Actual (Test)", color="black")
    plt.plot(dates_test, y_test_pred, label="Predicted (Test)", linestyle="--", color="red")
    plt.title(f"Actual vs Predicted: {y_col}")
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 4))
    plt.plot(data["Months"], y_current, label="Historical CPI", color="black")
    plt.plot(forecast_df["Months"], forecast_df["Forecasted CPI"], label="Forecasted CPI", color="green", marker="o")
    plt.title(f"Forecasted {y_col}")
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, forecast_df

# helper: find actual y column in dataframe using simple keyword matching
def find_y_col(df, domain_label):
    keyword_map = {
        "Food CPI": ["food"],
        "Housing CPI": ["housing", "house", "rent"],
        "Restaurant CPI": ["restaur", "restaurant", "restauration"],
        "Transportation CPI": ["transport", "transportation"]
    }
    kws = keyword_map.get(domain_label, [domain_label.split()[0].lower()])
    cols = df.columns.tolist()
    for kw in kws:
        for c in cols:
            if kw.lower() in str(c).lower():
                return c
    return None

# %%
# === Run for multiple domains ===
base_path = "/Users/harold/DataAnalyctisandScience/Cointegration_Johansen_test"

domain_files = {
    "Food CPI": f"{base_path}/dataFoodCPI/Ivoire_completes.xlsx",
    "Housing CPI": f"{base_path}/dataHousingCPI/Ivoire.xlsx",
    "Restaurant CPI": f"{base_path}/dataRestaurantCPI/Ivoire_completes.xlsx",
    "Transportation CPI": f"{base_path}/dataTransportationCPI/Ivoire_completes.xlsx",
}


n_forecast = 6
results = {}
selection_summaries = {}

for domain_label, file_path in domain_files.items():
    print(f"\n=== Processing file for {domain_label} ===")
    df = pd.read_excel(file_path)
    df["Months"] = pd.to_datetime(df["Months"])

    # detect dependent column name present in file
    y_col = find_y_col(df, domain_label)
    if y_col is None:
        print(f"  Skipping {domain_label}: could not find dependent column. Available columns: {df.columns.tolist()}")
        continue
    print(f"  Using dependent column: '{y_col}'")

    # model selection and run
    best_model_type, summary_df = select_best_model(df, y_col, candidate_models=None)
    selection_summaries[domain_label] = summary_df
    model, forecast_df = run_ols_forecast(df, y_col, best_model_type, n_forecast)
    results[domain_label] = {"model_type": best_model_type, "model": model, "forecast": forecast_df}
# Out:
# === Processing file for Food CPI ===
#   Using dependent column: 'Food CPI'
# Dropping 'FAO Sugar Index' (p-value = 0.8886)
# Dropping 'UCSB CHIRPS Rainfall: avg' (p-value = 0.7216)
# Dropping 'Rice, Thai 25%  ($/mt)' (p-value = 0.6607)
# Dropping 'Sorghum ($/mt)' (p-value = 0.6437)
# Dropping 'Palm kernel oil ($/mt)' (p-value = 0.6317)
# Dropping 'Soybean oil ($/mt)' (p-value = 0.6710)
# Dropping 'Wheat, US SRW ($/mt)' (p-value = 0.6152)
# Dropping 'Sugar, EU ($/kg)' (p-value = 0.3463)
# Dropping 'Wheat, US HRW ($/mt)' (p-value = 0.2002)
# Dropping 'Rice, Thai 25%  ($/mt)' (p-value = 0.9504)
# Dropping 'Wheat, US HRW ($/mt)' (p-value = 0.8996)
# Dropping 'Sugar, EU ($/kg)' (p-value = 0.8760)
# Dropping 'Soybean oil ($/mt)' (p-value = 0.8931)
# Dropping 'Palm kernel oil ($/mt)' (p-value = 0.8109)
# Dropping 'Maize ($/mt)' (p-value = 0.7678)
# Dropping 'Wheat, US SRW ($/mt)' (p-value = 0.5618)
# Dropping 'Beef ** ($/kg)' (p-value = 0.5532)
# Dropping 'lag_Wheat, US SRW ($/mt)' (p-value = 0.9369)
# Dropping 'lag_Rice, Thai 25%  ($/mt)' (p-value = 0.9170)
# Dropping 'lag_Palm kernel oil ($/mt)' (p-value = 0.8270)
# Dropping 'lag_Soybean oil ($/mt)' (p-value = 0.8419)
# Dropping 'lag_Beef ** ($/kg)' (p-value = 0.6833)
# Dropping 'lag_FAO Sugar Index' (p-value = 0.6555)
# Dropping 'lag_Sorghum ($/mt)' (p-value = 0.6446)
# Dropping 'lag_Sugar, EU ($/kg)' (p-value = 0.5337)
# Dropping 'lag_UCSB CHIRPS Rainfall: avg' (p-value = 0.1942)
# Dropping 'lag_Sugar, EU ($/kg)' (p-value = 0.9739)
# Dropping 'lag_Rice, Thai 25%  ($/mt)' (p-value = 0.7105)
# Dropping 'lag_Maize ($/mt)' (p-value = 0.7639)
# Dropping 'lag_Lamb ** ($/kg)' (p-value = 0.6906)
# Dropping 'lag_Rice, Viet Namese 5% ($/mt)' (p-value = 0.6854)
#
# Model selection results (sorted):
#   model_type  rmse_test          aic          bic       rsq
# 1         AR   1.739948  1039.770663  1046.655499  0.764980
# 4    AR_LagX   2.384855  1030.061120  1109.236727  0.812117
# 2        ARX   2.591554  1019.528834  1088.377189  0.815767
# 3       LagX   5.840528  1145.767315  1207.730834  0.676239
# 0       Base   6.170229  1150.089712  1212.130984  0.676501
#
# Selected best model: AR (rmse_test=1.7399, aic=1039.7706633463163)
#
# ========================================
# Processing domain: Food CPI | Model type: AR
# ========================================
# R² (train): 0.7650 | Adj R²: 0.7640
# RMSE (train): 2.2773 | RMSE (test): 1.7399
# === Processing file for Housing CPI ===
#   Using dependent column: 'House CPI'
#
# Model selection results (sorted):
#   model_type  rmse_test          aic          bic       rsq
# 1         AR   0.893570   824.842380   831.803658  0.769301
# 2        ARX   1.549796   819.760729   830.202646  0.776009
# 4    AR_LagX   1.579460   819.247746   829.689662  0.776487
# 0       Base   4.030569  1156.938481  1163.908075  0.093975
# 3       LagX   4.454306  1147.814170  1158.256087  0.121253
#
# Selected best model: AR (rmse_test=0.8936, aic=824.8423797237681)
#
# ========================================
# Processing domain: House CPI | Model type: AR
# ========================================
# R² (train): 0.7693 | Adj R²: 0.7683
# RMSE (train): 1.3380 | RMSE (test): 0.8936
# === Processing file for Restaurant CPI ===
#   Using dependent column: 'Restauration CPI'
# Dropping 'Tea, Mombasa ($/kg) TEA_MOMBASA' (p-value = 0.9125)
# Dropping 'Soybeans ($/mt) SOYBEANS' (p-value = 0.8714)
# Dropping 'Maize ($/mt) MAIZE' (p-value = 0.6684)
# Dropping 'Soybean oil ($/mt) SOYBEAN_OIL' (p-value = 0.5771)
# Dropping 'Groundnuts ($/mt) GRNUT' (p-value = 0.6046)
# Dropping 'Shrimps, Mexican ($/kg) SHRIMP_MEX' (p-value = 0.5155)
# Dropping 'Tea, avg 3 auctions ($/kg) TEA_AVG' (p-value = 0.4169)
# Dropping 'Barley ($/mt) BARLEY' (p-value = 0.3973)
# Dropping 'Rice, Thai 25% ($/mt) RICE_25' (p-value = 0.4289)
# Dropping 'Coconut oil ($/mt) COCONUT_OIL' (p-value = 0.4190)
# Dropping 'Wheat, US SRW ($/mt) WHEAT_US_SRW' (p-value = 0.4068)
# Dropping 'Natural gas, Europe ($/mmbtu) NGAS_EUR' (p-value = 0.3242)
# Dropping 'Rapeseed oil ($/mt) RAPESEED_OIL' (p-value = 0.2289)
# Dropping 'Palm kernel oil ($/mt) PLMKRNL_OIL' (p-value = 0.2996)
# Dropping 'Sugar, world ($/kg) SUGAR_WLD' (p-value = 0.1379)
# Dropping 'Fish meal ($/mt) FISH_MEAL' (p-value = 0.1061)
# Dropping 'Rice, Thai 25% ($/mt) RICE_25' (p-value = 0.9557)
# Dropping 'Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.9252)
# Dropping 'Wheat, US HRW ($/mt) WHEAT_US_HRW' (p-value = 0.8050)
# Dropping 'Orange ($/kg) ORANGE' (p-value = 0.7160)
# Dropping 'Coffee, Arabica ($/kg) COFFEE_ARABIC' (p-value = 0.7188)
# Dropping 'Soybean oil ($/mt) SOYBEAN_OIL' (p-value = 0.7349)
# Dropping 'Groundnuts ($/mt) GRNUT' (p-value = 0.6887)
# Dropping 'Coffee, Robusta ($/kg) COFFEE_ROBUS' (p-value = 0.6068)
# Dropping 'Soybeans ($/mt) SOYBEANS' (p-value = 0.4532)
# Dropping 'Fish meal ($/mt) FISH_MEAL' (p-value = 0.6167)
# Dropping 'Palm oil ($/mt) PALM_OIL' (p-value = 0.5339)
# Dropping 'Cocoa ($/kg) COCOA' (p-value = 0.4961)
# Dropping 'Sugar, EU ($/kg) SUGAR_EU' (p-value = 0.4115)
# Dropping 'Rapeseed oil ($/mt) RAPESEED_OIL' (p-value = 0.3187)
# Dropping 'Tea, avg 3 auctions ($/kg) TEA_AVG' (p-value = 0.3098)
# Dropping 'Maize ($/mt) MAIZE' (p-value = 0.2952)
# Dropping 'Rice, Viet Namese 5% ($/mt) RICE_05_VNM' (p-value = 0.2841)
# Dropping 'Sunflower oil ($/mt) SUNFLOWER_OIL' (p-value = 0.3164)
# Dropping 'Soybean meal ($/mt) SOYBEAN_MEAL' (p-value = 0.2266)
# Dropping 'Groundnut oil **($/mt) GRNUT_OIL' (p-value = 0.3378)
# Dropping 'Beef **($/kg) BEEF' (p-value = 0.2189)
# Dropping 'Banana, Europe ($/kg) BANANA_EU' (p-value = 0.2037)
# Dropping 'Banana, US ($/kg) BANANA_US' (p-value = 0.3273)
# Dropping 'Sugar, US ($/kg) SUGAR_US' (p-value = 0.2592)
# Dropping 'Sugar, world ($/kg) SUGAR_WLD' (p-value = 0.3208)
# Dropping 'Wheat, US SRW ($/mt) WHEAT_US_SRW' (p-value = 0.3403)
# Dropping 'Tea, Kolkata ($/kg) TEA_KOLKATA' (p-value = 0.3276)
# Dropping 'Shrimps, Mexican ($/kg) SHRIMP_MEX' (p-value = 0.2875)
# Dropping 'Chicken **($/kg) CHICKEN' (p-value = 0.2150)
# Dropping 'Sorghum ($/mt) SORGHUM' (p-value = 0.1798)
# Dropping 'Palm kernel oil ($/mt) PLMKRNL_OIL' (p-value = 0.2028)
# Dropping 'lag_Tea, Mombasa ($/kg) TEA_MOMBASA' (p-value = 0.9250)
# Dropping 'lag_Maize ($/mt) MAIZE' (p-value = 0.8924)
# Dropping 'lag_Rice, Thai 25% ($/mt) RICE_25' (p-value = 0.8154)
# Dropping 'lag_Soybean oil ($/mt) SOYBEAN_OIL' (p-value = 0.7555)
# Dropping 'lag_Groundnut oil **($/mt) GRNUT_OIL' (p-value = 0.6845)
# Dropping 'lag_Coconut oil ($/mt) COCONUT_OIL' (p-value = 0.5591)
# Dropping 'lag_Groundnuts ($/mt) GRNUT' (p-value = 0.5002)
# Dropping 'lag_Shrimps, Mexican ($/kg) SHRIMP_MEX' (p-value = 0.4191)
# Dropping 'lag_Barley ($/mt) BARLEY' (p-value = 0.3450)
# Dropping 'lag_Tea, avg 3 auctions ($/kg) TEA_AVG' (p-value = 0.3124)
# Dropping 'lag_Wheat, US HRW ($/mt) WHEAT_US_HRW' (p-value = 0.4557)
# Dropping 'lag_Natural gas, Europe ($/mmbtu) NGAS_EUR' (p-value = 0.2226)
# Dropping 'lag_Soybeans ($/mt) SOYBEANS' (p-value = 0.3326)
# Dropping 'lag_Rapeseed oil ($/mt) RAPESEED_OIL' (p-value = 0.4090)
# Dropping 'lag_Tea, avg 3 auctions ($/kg) TEA_AVG' (p-value = 0.9846)
# Dropping 'lag_Tea, Kolkata ($/kg) TEA_KOLKATA' (p-value = 0.9847)
# Dropping 'lag_Rice, Thai 5% ($/mt) RICE_05' (p-value = 0.8545)
# Dropping 'lag_Groundnut oil **($/mt) GRNUT_OIL' (p-value = 0.8216)
# Dropping 'lag_Soybean oil ($/mt) SOYBEAN_OIL' (p-value = 0.8097)
# Dropping 'lag_Shrimps, Mexican ($/kg) SHRIMP_MEX' (p-value = 0.7777)
# Dropping 'lag_Tea, Mombasa ($/kg) TEA_MOMBASA' (p-value = 0.6499)
# Dropping 'lag_Groundnuts ($/mt) GRNUT' (p-value = 0.7695)
# Dropping 'lag_Chicken **($/kg) CHICKEN' (p-value = 0.7707)
# Dropping 'lag_Beef **($/kg) BEEF' (p-value = 0.6706)
# Dropping 'lag_Rapeseed oil ($/mt) RAPESEED_OIL' (p-value = 0.5890)
# Dropping 'lag_Natural gas, Europe ($/mmbtu) NGAS_EUR' (p-value = 0.5337)
# Dropping 'lag_Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.5836)
# Dropping 'lag_Coffee, Arabica ($/kg) COFFEE_ARABIC' (p-value = 0.5172)
# Dropping 'lag_Soybeans ($/mt) SOYBEANS' (p-value = 0.4354)
# Dropping 'lag_Barley ($/mt) BARLEY' (p-value = 0.4897)
# Dropping 'lag_Maize ($/mt) MAIZE' (p-value = 0.7268)
# Dropping 'lag_Coconut oil ($/mt) COCONUT_OIL' (p-value = 0.3658)
# Dropping 'lag_Sorghum ($/mt) SORGHUM' (p-value = 0.3366)
# Dropping 'lag_Rice, Thai 25% ($/mt) RICE_25' (p-value = 0.4247)
# Dropping 'lag_Orange ($/kg) ORANGE' (p-value = 0.3952)
# Dropping 'lag_Wheat, US SRW ($/mt) WHEAT_US_SRW' (p-value = 0.4078)
# Dropping 'lag_Rice, Viet Namese 5% ($/mt) RICE_05_VNM' (p-value = 0.1978)
# Dropping 'lag_Soybean meal ($/mt) SOYBEAN_MEAL' (p-value = 0.3482)
# Dropping 'lag_Sugar, EU ($/kg) SUGAR_EU' (p-value = 0.2622)
# Dropping 'lag_Wheat, US HRW ($/mt) WHEAT_US_HRW' (p-value = 0.2549)
# Dropping 'lag_Cocoa ($/kg) COCOA' (p-value = 0.1991)
# Dropping 'lag_Sunflower oil ($/mt) SUNFLOWER_OIL' (p-value = 0.1150)
#
# Model selection results (sorted):
#   model_type  rmse_test          aic          bic       rsq
# 1         AR   0.029929 -1451.093049 -1440.727085  0.837206
# 4    AR_LagX   0.030988 -1478.387332 -1433.468157  0.866996
# 2        ARX   0.033130 -1474.277936 -1439.724725  0.861124
# 3       LagX   0.067234 -1263.496188 -1173.657839  0.701848
# 0       Base   0.068955 -1249.588516 -1166.558463  0.674307
#
# Selected best model: AR (rmse_test=0.0299, aic=-1451.0930485328636)
#
# ========================================
# Processing domain: Restauration CPI | Model type: AR
# ========================================
# R² (train): 0.8372 | Adj R²: 0.8358
# RMSE (train): 0.0108 | RMSE (test): 0.0299
# === Processing file for Transportation CPI ===
#   Using dependent column: 'transportation CPI'
# Dropping 'Liquefied natural gas, Japan ($/mmbtu) NGAS_JP' (p-value = 0.9576)
# Dropping 'Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.8098)
# Dropping 'Coal, Australian ($/mt) COAL_AUS' (p-value = 0.3613)
# Dropping 'Coal, South African **($/mt) COAL_SAFRICA' (p-value = 0.5396)
# Dropping 'Natural gas, Europe ($/mmbtu) NGAS_EUR' (p-value = 0.9802)
# Dropping 'Liquefied natural gas, Japan ($/mmbtu) NGAS_JP' (p-value = 0.7999)
# Dropping 'Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.6148)
# Dropping 'Coal, Australian ($/mt) COAL_AUS' (p-value = 0.2992)
# Dropping 'Coal, South African **($/mt) COAL_SAFRICA' (p-value = 0.3901)
# Dropping 'lag_Liquefied natural gas, Japan ($/mmbtu) NGAS_JP' (p-value = 0.9747)
# Dropping 'lag_Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.5461)
# Dropping 'lag_Coal, Australian ($/mt) COAL_AUS' (p-value = 0.3218)
# Dropping 'lag_Coal, South African **($/mt) COAL_SAFRICA' (p-value = 0.6885)
# Dropping 'lag_Coal, Australian ($/mt) COAL_AUS' (p-value = 0.9239)
# Dropping 'lag_Natural gas, Europe ($/mmbtu) NGAS_EUR' (p-value = 0.9175)
# Dropping 'lag_Coal, South African **($/mt) COAL_SAFRICA' (p-value = 0.7509)
# Dropping 'lag_Liquefied natural gas, Japan ($/mmbtu) NGAS_JP' (p-value = 0.6547)
# Dropping 'lag_Natural gas, US ($/mmbtu) NGAS_US' (p-value = 0.3832)
# Dropping 'lag_Crude oil, Brent ($/bbl) CRUDE_BRENT' (p-value = 0.1164)
# Dropping 'lag_Crude oil, WTI ($/bbl) CRUDE_WTI' (p-value = 0.2827)
#
# Model selection results (sorted):
#   model_type  rmse_test          aic          bic       rsq
# 1         AR   0.033155 -1214.718643 -1204.352680  0.847105
# 4    AR_LagX   0.034493 -1241.271323 -1227.450038  0.864668
# 2        ARX   0.035733 -1237.931509 -1217.199582  0.865049
# 3       LagX   0.180500  -857.487360  -836.755434  0.314093
# 0       Base   0.191728  -859.659253  -838.901740  0.309107
#
# Selected best model: AR (rmse_test=0.0332, aic=-1214.7186432872513)
#
# ========================================
# Processing domain: transportation CPI | Model type: AR
# ========================================
# R² (train): 0.8471 | Adj R²: 0.8458
# RMSE (train): 0.0178 | RMSE (test): 0.0332

# %%
# print compact summary
for domain, info in results.items():
    print(f"\n{domain} -> selected model: {info['model_type']}")
    print(info["forecast"])
# Out:
# Food CPI -> selected model: AR
#       Months  Forecasted CPI
# 0 2025-03-01        1.834971
# 1 2025-04-01        1.603390
# 2 2025-05-01        1.401035
# 3 2025-06-01        1.224219
# 4 2025-07-01        1.069717
# 5 2025-08-01        0.934714
#
# Housing CPI -> selected model: AR
#       Months  Forecasted CPI
# 0 2025-03-01       -2.194713
# 1 2025-04-01       -1.926706
# 2 2025-05-01       -1.691427
# 3 2025-06-01       -1.484878
# 4 2025-07-01       -1.303553
# 5 2025-08-01       -1.144369
#
# Restaurant CPI -> selected model: AR
#       Months  Forecasted CPI
# 0 2025-07-01       -0.009818
# 1 2025-08-01       -0.008912
# 2 2025-09-01       -0.008090
# 3 2025-10-01       -0.007344
# 4 2025-11-01       -0.006666
# 5 2025-12-01       -0.006051
#
# Transportation CPI -> selected model: AR
#       Months  Forecasted CPI
# 0 2025-07-01       -0.007145
# 1 2025-08-01       -0.006572
# 2 2025-09-01       -0.006046
# 3 2025-10-01       -0.005562
# 4 2025-11-01       -0.005116
# 5 2025-12-01       -0.004706
