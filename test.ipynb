# %%
pip install sdmx1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install msal
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 3.1 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [msal]3/5 [cryptography]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import sdmx

# %%
# retrieve data

IMF_DATA = sdmx.Client('IMF_DATA')

data_msg = IMF_DATA.data('CPI', key='USA+CAN.CPI.CP01.IX.M', params={'startPeriod': 2018})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # retrieve data
# ----> 3 IMF_DATA = sdmx.Client('IMF_DATA')
#       5 data_msg = IMF_DATA.data('CPI', key='USA+CAN.CPI.CP01.IX.M', params={'startPeriod': 2018})
#
# AttributeError: module 'sdmx' has no attribute 'Client'

# %%
 

# convert to pandas

cpi_df = sdmx.to_pandas(data_msg)

print(cpi_df.head())

# %%
# import libraries

import  sdmx

from msal import PublicClientApplication

 

# parameter values for authorization and data requests

client_id = '446ce2fa-88b1-436c-b8e6-94491ca4f6fb'

authority = 'https://imfprdb2c.b2clogin.com/imfprdb2c.onmicrosoft.com/b2c_1a_signin_aad_simple_user_journey/'

scope = 'https://imfprdb2c.onmicrosoft.com/4042e178-3e2f-4ff9-ac38-1276c901c13d/iData.Login'

# authorize and retrieve access token

app = PublicClientApplication(client_id,authority=authority)

token = None

token = app.acquire_token_interactive(scopes=[scope])

# define header for a request

header = {'Authorization': f"{token['token_type']} {token['access_token']}"}

 

# retrieve data

IMF_DATA = sdmx.Client('IMF_DATA')

data_msg = IMF_DATA.data('CPI', key='USA+CAN.CPI.CP01.IX.M', params={'startPeriod': 2018}, headers=header)

 

# convert to pandas

cpi_df = sdmx.to_pandas(data_msg)

print(cpi_df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 33
#      27 header = {'Authorization': f"{token['token_type']} {token['access_token']}"}
#      31 # retrieve data
# ---> 33 IMF_DATA = sdmx.Client('IMF_DATA')
#      35 data_msg = IMF_DATA.data('CPI', key='USA+CAN.CPI.CP01.IX.M', params={'startPeriod': 2018}, headers=header)
#      39 # convert to pandas
#
# AttributeError: module 'sdmx' has no attribute 'Client'

# %%
pip install pandasdmx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandasdmx]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandasdmx

# Créer une requête vers la source "IMF"
req = pandasdmx.Request('IMF')

# Obtenir les structures disponibles (facultatif)
flows = req.dataflow()
print(list(flows.dataflow.keys())[:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandasdmx
#       3 # Créer une requête vers la source "IMF"
#       4 req = pandasdmx.Request('IMF')
#
# File ~/DataAnalyctisandScience/Cointegration_Johansen_test/.venv/lib/python3.13/site-packages/pandasdmx/__init__.py:4
#       1 """Statistical Data and Metadata eXchange (SDMX) for the Python data ecosystem"""
# ----> 4 from pandasdmx.api import Request, read_url
#       5 from pandasdmx.reader import read_sdmx
#       6 from pandasdmx.source import add_source, list_sources
#
# File ~/DataAnalyctisandScience/Cointegration_Johansen_test/.venv/lib/python3.13/site-packages/pandasdmx/api.py:16
#      13 import requests
#      15 from pandasdmx import remote
# ---> 16 from pandasdmx.reader import get_reader_for_content_type
#      18 from .message import Message
# ...

# %%
import requests
import pandas as pd

url = "https://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/IFS/Q.CIV.NGDP_R_PC"
response = requests.get(url)
data = response.json()

# Extraction du tableau
obs = data['CompactData']['DataSet']['Series']['Obs']
df = pd.DataFrame(obs)
df.columns = ['Time', 'PIB_Reel']
df['PIB_Reel'] = df['PIB_Reel'].astype(float)
df['Time'] = pd.to_datetime(df['Time'])
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/DataAnalyctisandScience/Cointegration_Johansen_test/.venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/DataAnalyctisandScience/Cointegration_Johansen_test/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
